# %%
import requests
import pandas as pd
from io import StringIO

# %%
url = "https://data.ssb.no/api/v0/no/table/08329/"

# %% [markdown]
# Argumentene under følger APIet til SSB.
# Dette er dokumentert her: [https://www.ssb.no/api/pxwebapi](https://www.ssb.no/api/pxwebapi)

# %%
args = {
  "query": [
    {
      "code": "Skadegrad",
      "selection": {
        "filter": "all",
        "values": ["*"]
      }
    },
    {
      "code": "Ulukkesgruppe",
      "selection": {
        "filter": "all",
        "values": [
          "*"
        ]
      }
    },
      {
      "code": "VegtrTrafGrp",
      "selection": {
        "filter": "all",
        "values": [
          "*"
        ]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "all",
        "values": [
          "*"
        ]
      }
    },
    {
      "code": "Tid",
      "selection": {
        "filter": "all",
        "values": [
          "*"
        ]
      }
    }
  ],
  "response": {
    "format": "csv2"
  }
}

# %%
resp = requests.post(url, json=args)

# %% [markdown]
# StringIO er et teknisk triks for å få en streng til å se ut som om den er en fil med tekst.

# %%
df = pd.read_csv(StringIO(resp.text))

# %%
df
# Out:
#                  skadegrad    trafikantgruppe           ulykkestype    måned  \
# 0                    Drept          Bilførere   A. Påkjøring bakfra  1999M01
# 1                    Drept          Bilførere   A. Påkjøring bakfra  1999M02
# 2                    Drept          Bilførere   A. Påkjøring bakfra  1999M03
# 3                    Drept          Bilførere   A. Påkjøring bakfra  1999M04
# 4                    Drept          Bilførere   A. Påkjøring bakfra  1999M05
# ...                    ...                ...                   ...      ...
# 170491  Uoppgitt skadegrad  Andre trafikanter      L. Andre ulykker  2023M04
# 170492  Uoppgitt skadegrad  Andre trafikanter      L. Andre ulykker  2023M05
# 170493  Uoppgitt skadegrad  Andre trafikanter      L. Andre ulykker  2023M06
# 170494  Uoppgitt skadegrad  Andre trafikanter      L. Andre ulykker  2023M07
# 170495  Uoppgitt skadegrad  Andre trafikanter      L. Andre ulykker  2023M08
#
#                 statistikkvariabel  \
# 0       Personer drept eller skadd
# 1       Personer drept eller skadd
# 2       Personer drept eller skadd
# 3       Personer drept eller skadd
# 4       Personer drept eller skadd
# ...                            ...
# 170491  Personer drept eller skadd
# 170492  Personer drept eller skadd
# 170493  Personer drept eller skadd
# 170494  Personer drept eller skadd
# 170495  Personer drept eller skadd
#
#         08329: Drepte eller skadde i trafikkulykker,
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 170491                                             0
# 170492                                             0
# 170493                                             0
# 170494                                             0
# 170495                                             0
#
# [170496 rows x 6 columns]

# %%
df["ulykkestype"].unique()
# Out:
# array(['\xa0A. Påkjøring bakfra',
#        '\xa0B. Andre ulykker med samme kjøreretning',
#        '\xa0C. Møting ved forbikjøring', '\xa0D. Andre møteulykker',
#        '\xa0E. Samme og motsatt kjøreretning med avsvinging',
#        '\xa0F. Kryssende kjøreretning',
#        '\xa0G. Fotgjenger krysset kjørebanen',
#        '\xa0H. Fotgjenger gikk langs eller oppholdt seg i kjørebanen',
#        '\xa0I. Akende o.l.', '\xa0J. Enslig kjøretøy utfor veien',
#        '\xa0K. Enslig kjøretøy veltet i kjørebanen. Påkjøring av dyr, parkerte biler mv.',
#        '\xa0L. Andre ulykker'], dtype=object)
